# %% [markdown]
# EXPERIMENT 4: Write a python program to import and export data using Pandas and show the details of the dataset like number of rows, columns, first five rows, size, number of missing values, sum, average, min and max values from the nume
#
# ```
# # This is formatted as code

# %%
import pandas as pd

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-42a0c7b5-09d0-4000-88b1-45263bf83419" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-42a0c7b5-09d0-4000-88b1-45263bf83419">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files

# %%
import io

# %%
df=pd.read_csv(io.BytesIO(uploaded ['industry.csv']))

# %%
df.head(5)
# Out:
#                         Industry
# 0             Accounting/Finance
# 1   Advertising/Public Relations
# 2             Aerospace/Aviation
# 3  Arts/Entertainment/Publishing
# 4                     Automotive

# %%
df.tail(5)
# Out:
#                     Industry
# 38             Skilled Labor
# 39                Technology
# 40        Telecommunications
# 41  Transportation/Logistics
# 42                     Other

# %%
df.describe()
# Out:
#                   Industry
# count                   43
# unique                  43
# top     Accounting/Finance
# freq                     1

# %%
df.isna().sum()
# Out:
# Industry    0
# dtype: int64

# %%
df.sum(numeric_only = True)
# Out:
# Series([], dtype: float64)

# %%
df.mean(numeric_only=True)
# Out:
# Series([], dtype: float64)

# %%
df.min(numeric_only=True)
# Out:
# Series([], dtype: float64)

# %%
df.max(numeric_only=True)
# Out:
# Series([], dtype: float64)

# %%
df.size
# Out:
# 43
